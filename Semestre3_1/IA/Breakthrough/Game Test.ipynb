# %%
from IIA2223 import *
from jogar import *
game = JogoBT_69420()
j1 = JogadorAlfaBeta('Off    ', 3, func_eval_o)
j2 = JogadorAlfaBeta('OffSqr ', 3, func_eval_osqr)
j3 = JogadorAlfaBeta('Def    ', 3, func_eval_d)
j4 = JogadorAlfaBeta('DefSqr ', 3, func_eval_dsqr)
j5 = JogadorAlfaBeta('Mix    ', 3, func_eval_m)
j6 = JogadorAlfaBeta('MixSqr ', 3, func_eval_msqr)
j7 = JogadorAlfaBeta('MixSqr3', 3, func_eval_msqr3)
j8 = JogadorAlfaBeta('MixSqr5', 3, func_eval_msqr5)
faz_campeonato(game, [j1, j2, j3, j4, j5, j6, j7, j8], 12)
# Out:
# 1 Off     OffSqr  --vencedor= OffSqr
# 2 Off     OffSqr  --vencedor= OffSqr
# 3 Off     OffSqr  --vencedor= OffSqr
# 4 Off     Def     --vencedor= Off
# 5 Off     Def     --vencedor= Off
# 6 Off     Def     --vencedor= Off
# 7 Off     DefSqr  --vencedor= Off
# 8 Off     DefSqr  --vencedor= Off
# 9 Off     DefSqr  --vencedor= DefSqr
# 10 Off     Mix     --vencedor= Off
# 11 Off     Mix     --vencedor= Mix
# 12 Off     Mix     --vencedor= Mix
# 13 Off     MixSqr  --vencedor= MixSqr
# 14 Off     MixSqr  --vencedor= MixSqr
# 15 Off     MixSqr  --vencedor= Off
# 16 Off     MixSqr3 --vencedor= MixSqr3
# 17 Off     MixSqr3 --vencedor= MixSqr3
# 18 Off     MixSqr3 --vencedor= MixSqr3
# 19 Off     MixSqr5 --vencedor= MixSqr5
# 20 Off     MixSqr5 --vencedor= MixSqr5
# 21 Off     MixSqr5 --vencedor= MixSqr5
# 22 OffSqr  Off     --vencedor= OffSqr
# 23 OffSqr  Off     --vencedor= Off
# 24 OffSqr  Off     --vencedor= OffSqr
# 25 OffSqr  Def     --vencedor= OffSqr
# 26 OffSqr  Def     --vencedor= OffSqr
# 27 OffSqr  Def     --vencedor= OffSqr
# 28 OffSqr  DefSqr  --vencedor= OffSqr
# 29 OffSqr  DefSqr  --vencedor= OffSqr
# 30 OffSqr  DefSqr  --vencedor= OffSqr
# 31 OffSqr  Mix     --vencedor= OffSqr
# 32 OffSqr  Mix     --vencedor= OffSqr
# 33 OffSqr  Mix     --vencedor= OffSqr
# 34 OffSqr  MixSqr  --vencedor= OffSqr
# pim! OffSqr
# 35 OffSqr  MixSqr  --vencedor= MixSqr
# 36 OffSqr  MixSqr  --vencedor= OffSqr
# 37 OffSqr  MixSqr3 --vencedor= MixSqr3
# 38 OffSqr  MixSqr3 --vencedor= OffSqr
# pim! OffSqr
# 39 OffSqr  MixSqr3 --vencedor= MixSqr3
# pim! OffSqr
# 40 OffSqr  MixSqr5 --vencedor= MixSqr5
# 41 OffSqr  MixSqr5 --vencedor= MixSqr5
# 42 OffSqr  MixSqr5 --vencedor= MixSqr5
# 43 Def     Off     --vencedor= Off
# 44 Def     Off     --vencedor= Off
# 45 Def     Off     --vencedor= Off
# 46 Def     OffSqr  --vencedor= OffSqr
# 47 Def     OffSqr  --vencedor= OffSqr
# 48 Def     OffSqr  --vencedor= OffSqr
# 49 Def     DefSqr  --vencedor= Def
# 50 Def     DefSqr  --vencedor= Def
# 51 Def     DefSqr  --vencedor= Def
# 52 Def     Mix     --vencedor= Mix
# 53 Def     Mix     --vencedor= Mix
# 54 Def     Mix     --vencedor= Mix
# 55 Def     MixSqr  --vencedor= MixSqr
# 56 Def     MixSqr  --vencedor= MixSqr
# 57 Def     MixSqr  --vencedor= MixSqr
# 58 Def     MixSqr3 --vencedor= MixSqr3
# 59 Def     MixSqr3 --vencedor= MixSqr3
# 60 Def     MixSqr3 --vencedor= MixSqr3
# 61 Def     MixSqr5 --vencedor= MixSqr5
# 62 Def     MixSqr5 --vencedor= MixSqr5
# 63 Def     MixSqr5 --vencedor= MixSqr5
# 64 DefSqr  Off     --vencedor= Off
# 65 DefSqr  Off     --vencedor= DefSqr
# 66 DefSqr  Off     --vencedor= Off
# 67 DefSqr  OffSqr  --vencedor= OffSqr
# 68 DefSqr  OffSqr  --vencedor= OffSqr
# 69 DefSqr  OffSqr  --vencedor= OffSqr
# 70 DefSqr  Def     --vencedor= Def
# 71 DefSqr  Def     --vencedor= Def
# 72 DefSqr  Def     --vencedor= Def
# 73 DefSqr  Mix     --vencedor= Mix
# 74 DefSqr  Mix     --vencedor= Mix
# 75 DefSqr  Mix     --vencedor= Mix
# 76 DefSqr  MixSqr  --vencedor= MixSqr
# 77 DefSqr  MixSqr  --vencedor= MixSqr
# 78 DefSqr  MixSqr  --vencedor= MixSqr
# 79 DefSqr  MixSqr3 --vencedor= MixSqr3
# 80 DefSqr  MixSqr3 --vencedor= MixSqr3
# 81 DefSqr  MixSqr3 --vencedor= MixSqr3
# 82 DefSqr  MixSqr5 --vencedor= MixSqr5
# 83 DefSqr  MixSqr5 --vencedor= MixSqr5
# 84 DefSqr  MixSqr5 --vencedor= MixSqr5
# 85 Mix     Off     --vencedor= Mix
# 86 Mix     Off     --vencedor= Mix
# 87 Mix     Off     --vencedor= Mix
# 88 Mix     OffSqr  --vencedor= Mix
# 89 Mix     OffSqr  --vencedor= OffSqr
# 90 Mix     OffSqr  --vencedor= OffSqr
# 91 Mix     Def     --vencedor= Mix
# 92 Mix     Def     --vencedor= Mix
# 93 Mix     Def     --vencedor= Mix
# 94 Mix     DefSqr  --vencedor= Mix
# 95 Mix     DefSqr  --vencedor= Mix
# 96 Mix     DefSqr  --vencedor= Mix
# 97 Mix     MixSqr  --vencedor= MixSqr
# 98 Mix     MixSqr  --vencedor= MixSqr
# 99 Mix     MixSqr  --vencedor= MixSqr
# 100 Mix     MixSqr3 --vencedor= MixSqr3
# 101 Mix     MixSqr3 --vencedor= MixSqr3
# 102 Mix     MixSqr3 --vencedor= MixSqr3
# 103 Mix     MixSqr5 --vencedor= Mix
# 104 Mix     MixSqr5 --vencedor= Mix
# 105 Mix     MixSqr5 --vencedor= MixSqr5
# 106 MixSqr  Off     --vencedor= MixSqr
# 107 MixSqr  Off     --vencedor= MixSqr
# 108 MixSqr  Off     --vencedor= MixSqr
# 109 MixSqr  OffSqr  --vencedor= MixSqr
# 110 MixSqr  OffSqr  --vencedor= OffSqr
# 111 MixSqr  OffSqr  --vencedor= MixSqr
# 112 MixSqr  Def     --vencedor= MixSqr
# 113 MixSqr  Def     --vencedor= MixSqr
# 114 MixSqr  Def     --vencedor= MixSqr
# 115 MixSqr  DefSqr  --vencedor= MixSqr
# 116 MixSqr  DefSqr  --vencedor= MixSqr
# 117 MixSqr  DefSqr  --vencedor= MixSqr
# 118 MixSqr  Mix     --vencedor= MixSqr
# 119 MixSqr  Mix     --vencedor= MixSqr
# 120 MixSqr  Mix     --vencedor= MixSqr
# 121 MixSqr  MixSqr3 --vencedor= MixSqr3
# 122 MixSqr  MixSqr3 --vencedor= MixSqr3
# 123 MixSqr  MixSqr3 --vencedor= MixSqr3
# 124 MixSqr  MixSqr5 --vencedor= MixSqr
# 125 MixSqr  MixSqr5 --vencedor= MixSqr
# 126 MixSqr  MixSqr5 --vencedor= MixSqr
# 127 MixSqr3 Off     --vencedor= MixSqr3
# 128 MixSqr3 Off     --vencedor= MixSqr3
# 129 MixSqr3 Off     --vencedor= MixSqr3
# 130 MixSqr3 OffSqr  --vencedor= MixSqr3
# 131 MixSqr3 OffSqr  --vencedor= MixSqr3
# 132 MixSqr3 OffSqr  --vencedor= OffSqr
# 133 MixSqr3 Def     --vencedor= MixSqr3
# 134 MixSqr3 Def     --vencedor= MixSqr3
# 135 MixSqr3 Def     --vencedor= MixSqr3
# 136 MixSqr3 DefSqr  --vencedor= MixSqr3
# 137 MixSqr3 DefSqr  --vencedor= MixSqr3
# 138 MixSqr3 DefSqr  --vencedor= MixSqr3
# 139 MixSqr3 Mix     --vencedor= MixSqr3
# 140 MixSqr3 Mix     --vencedor= MixSqr3
# 141 MixSqr3 Mix     --vencedor= Mix
# 142 MixSqr3 MixSqr  --vencedor= MixSqr
# 143 MixSqr3 MixSqr  --vencedor= MixSqr3
# 144 MixSqr3 MixSqr  --vencedor= MixSqr3
# 145 MixSqr3 MixSqr5 --vencedor= MixSqr3
# 146 MixSqr3 MixSqr5 --vencedor= MixSqr3
# 147 MixSqr3 MixSqr5 --vencedor= MixSqr3
# 148 MixSqr5 Off     --vencedor= MixSqr5
# 149 MixSqr5 Off     --vencedor= MixSqr5
# 150 MixSqr5 Off     --vencedor= MixSqr5
# 151 MixSqr5 OffSqr  --vencedor= MixSqr5
# 152 MixSqr5 OffSqr  --vencedor= MixSqr5
# 153 MixSqr5 OffSqr  --vencedor= MixSqr5
# 154 MixSqr5 Def     --vencedor= MixSqr5
# 155 MixSqr5 Def     --vencedor= MixSqr5
# 156 MixSqr5 Def     --vencedor= MixSqr5
# 157 MixSqr5 DefSqr  --vencedor= MixSqr5
# 158 MixSqr5 DefSqr  --vencedor= MixSqr5
# 159 MixSqr5 DefSqr  --vencedor= MixSqr5
# 160 MixSqr5 Mix     --vencedor= Mix
# 161 MixSqr5 Mix     --vencedor= MixSqr5
# 162 MixSqr5 Mix     --vencedor= MixSqr5
# 163 MixSqr5 MixSqr  --vencedor= MixSqr
# 164 MixSqr5 MixSqr  --vencedor= MixSqr5
# 165 MixSqr5 MixSqr  --vencedor= MixSqr
# 166 MixSqr5 MixSqr3 --vencedor= MixSqr5
# 167 MixSqr5 MixSqr3 --vencedor= MixSqr3
# 168 MixSqr5 MixSqr3 --vencedor= MixSqr3
# JOGADOR VITÓRIAS
# MixSqr3       37
# MixSqr        32
# MixSqr5       29
# OffSqr        27
# Mix           22
# Off           13
# Def            6
# DefSqr         2
